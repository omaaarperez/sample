# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_champ = pd.read_csv('championsdata.csv')
df_champ.head()
# Out:
#    Year    Team  Game  Win  Home   MP  FG  FGA    FGP  TP ...     FTP  ORB  \
# 0  1980  Lakers     1    1     1  240  48   89  0.539   0 ...   0.867   12
# 1  1980  Lakers     2    0     1  240  48   95  0.505   0 ...   0.667   15
# 2  1980  Lakers     3    1     0  240  44   92  0.478   0 ...   0.767   22
# 3  1980  Lakers     4    0     0  240  44   93  0.473   0 ...   0.737   18
# 4  1980  Lakers     5    1     1  240  41   91  0.451   0 ...   0.788   19
#
#    DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 0   31   43   30    5    9   17  24  109
# 1   37   52   32   12    7   26  27  104
# 2   34   56   20    5    5   20  25  111
# 3   31   49   23   12    6   19  22  102
# 4   37   56   28    7    6   21  27  108
#
# [5 rows x 24 columns]

# %%
df_runnerup = pd.read_csv('runnerupsdata.csv')
df_runnerup.head()
# Out:
#    Year    Team  Game  Win  Home   MP  FG  FGA    FGP  TP ...     FTP  ORB  \
# 0  1980  Sixers     1    0     0  240  40   90  0.444   0 ...   0.786   14
# 1  1980  Sixers     2    1     0  240  43   85  0.506   0 ...   0.778    5
# 2  1980  Sixers     3    0     1  240  45   93  0.484   1 ...   0.588   13
# 3  1980  Sixers     4    1     1  240  41   79  0.519   0 ...   0.885    5
# 4  1980  Sixers     5    0     0  240  42   94  0.447   0 ...   0.792   13
#
#    DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 0   26   40   28   12   13   14  17  102
# 1   29   34   34   14   11   20  21  107
# 2   24   37   34   12    8   13  25  101
# 3   29   34   31    5   10   14  20  105
# 4   29   42   32    9    7   12  25  103
#
# [5 rows x 24 columns]

# %%
df = pd.concat([df_champ, df_runnerup]).reset_index()
df.drop(columns='index',inplace=True)

# %%
df['Team'].unique()
# Out:
# array(['Lakers', 'Celtics', 'Sixers', 'Pistons', 'Bulls', 'Rockets',
#        'Spurs', 'Heat', 'Mavericks', "'Heat'", 'Warriors', 'Cavaliers',
#        'Warriorrs', 'Blazers', 'Suns', 'Knicks', 'Magic', 'Sonics',
#        'Jazz', 'Pacers', 'Nets', 'Thunder'], dtype=object)

# %%
df[df['Team']=="'Heat'"]
# Out:
#      Year    Team  Game  Win  Home   MP  FG  FGA    FGP  TP ...     FTP  ORB  \
# 186  2012  'Heat'     1    0     1  240  34   78  0.436   8 ...   0.706    9
#
#      DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 186   37   46   20    4    2    8  12   88
#
# [1 rows x 24 columns]

# %%
df[df['Team']=='Warriorrs']
# Out:
#      Year       Team  Game  Win  Home   MP  FG  FGA    FGP  TP ...    FTP  \
# 214  2017  Warriorrs     4    0     0  240  39   87  0.448  11 ...   0.75
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 214   16   24   40   26    5    6   12  27  116
#
# [1 rows x 24 columns]

# %%
df[df['Year']==2012]
# Out:
#      Year     Team  Game  Win  Home   MP  FG  FGA    FGP  TP ...     FTP  ORB  \
# 181  2012     Heat     1    0     0  240  36   78  0.462   8 ...   0.778    7
# 182  2012     Heat     2    1     0  240  36   76  0.474   6 ...   0.880   11
# 183  2012     Heat     3    1     1  240  28   74  0.378   4 ...   0.886   14
# 184  2012     Heat     4    1     1  240  38   79  0.481  10 ...   0.720    9
# 185  2012     Heat     5    1     1  240  40   77  0.519  14 ...   0.818    8
# 186  2012   'Heat'     1    0     1  240  34   78  0.436   8 ...   0.706    9
# 401  2012  Thunder     1    1     1  240  40   77  0.519   5 ...   0.741   10
# 402  2012  Thunder     2    0     1  240  34   79  0.430   9 ...   0.731   10
# 403  2012  Thunder     3    0     0  240  33   77  0.429   4 ...   0.625   11
# 404  2012  Thunder     4    0     0  240  40   82  0.488   3 ...   0.938    8
# 405  2012  Thunder     5    0     0  240  36   87  0.414  11 ...   0.885   10
#
# ...

# %%
df[df['Year']==2013]
# Out:
#      Year   Team  Game  Win  Home   MP  FG  FGA    FGP  TP ...     FTP  ORB  \
# 187  2013   Heat     2    1     1  240  41   83  0.494  10 ...   0.786    9
# 188  2013   Heat     3    0     0  240  31   76  0.408   8 ...   0.700    9
# 189  2013   Heat     4    1     0  240  45   85  0.529   4 ...   0.882    7
# 190  2013   Heat     5    0     0  240  37   86  0.430  11 ...   0.826   12
# 191  2013   Heat     6    1     1  265  38   81  0.469  11 ...   0.762   12
# 192  2013   Heat     7    1     1  240  36   82  0.439  12 ...   0.688   11
# 406  2013  Spurs     1    1     0  240  35   84  0.417   7 ...   0.833    6
# 407  2013  Spurs     2    0     0  240  32   78  0.410  10 ...   0.714   15
# 408  2013  Spurs     3    1     1  240  43   88  0.489  16 ...   0.579   19
# 409  2013  Spurs     4    0     1  240  31   70  0.443   8 ...   0.742    5
# 410  2013  Spurs     5    1     1  240  42   70  0.600   9 ...   0.808    5
# ...

# %%
df.loc[186, 'Year'] = 2013
df.loc[186, 'Team'] = 'Heat'

# %%
df[df['Year']==2017]
# Out:
#      Year       Team  Game  Win  Home   MP  FG  FGA    FGP  TP ...     FTP  \
# 211  2017   Warriors     1    1     1  240  45  106  0.425  12 ...   0.688
# 212  2017   Warriors     2    1     1  240  46   89  0.517  18 ...   0.917
# 213  2017   Warriors     3    1     0  240  40   83  0.482  16 ...   0.917
# 214  2017  Warriorrs     4    0     0  240  39   87  0.448  11 ...   0.750
# 215  2017   Warriors     5    1     1  240  46   90  0.511  14 ...   0.821
# 431  2017  Cavaliers     1    0     0  240  30   86  0.349  11 ...   0.800
# 432  2017  Cavaliers     2    0     0  240  45  100  0.450   8 ...   0.789
# 433  2017  Cavaliers     3    0     1  240  40   90  0.444  12 ...   0.840
# 434  2017  Cavaliers     4    1     1  240  46   87  0.529  24 ...   0.677
# 435  2017  Cavaliers     5    0     0  240  47   88  0.534  11 ...   0.652
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 211   14   36   50   31   12    3    4  24  113
# ...

# %%
df.loc[214, 'Team'] = 'Warriors'

# %%
df.columns
# Out:
# Index(['Year', 'Team', 'Game', 'Win', 'Home', 'MP', 'FG', 'FGA', 'FGP', 'TP',
#        'TPA', 'TPP', 'FT', 'FTA', 'FTP', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 24 columns):
# Year    440 non-null int64
# Team    440 non-null object
# Game    440 non-null int64
# Win     440 non-null int64
# Home    440 non-null int64
# MP      440 non-null int64
# FG      440 non-null int64
# FGA     440 non-null int64
# FGP     440 non-null float64
# TP      440 non-null int64
# TPA     440 non-null int64
# TPP     431 non-null float64
# FT      440 non-null int64
# FTA     440 non-null int64
# FTP     440 non-null float64
# ORB     440 non-null int64
# DRB     440 non-null int64
# TRB     440 non-null int64
# AST     440 non-null int64
# STL     440 non-null int64
# BLK     440 non-null int64
# TOV     440 non-null int64
# PF      440 non-null int64
# PTS     440 non-null int64
# dtypes: float64(3), int64(20), object(1)
# memory usage: 82.6+ KB

# %%
df[df['TPP'].isna()][['TP', 'TPA','TPP']]
# Out:
#      TP  TPA  TPP
# 0     0    0  NaN
# 3     0    0  NaN
# 4     0    0  NaN
# 12    0    0  NaN
# 17    0    0  NaN
# 18    0    0  NaN
# 223   0    0  NaN
# 236   0    0  NaN
# 245   0    0  NaN

# %%
df['TPP'] = df['TPP'].fillna(0)

# %%
df[df['Winning Team']==True]['Team'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Winning Team'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-341-ffcfe9cec7d1> in <module>()
# ...

# %%
df.head(10)
# Out:
#    Year     Team  Game  Win  Home   MP  FG  FGA    FGP  TP ...     FTP  ORB  \
# 0  1980   Lakers     1    1     1  240  48   89  0.539   0 ...   0.867   12
# 1  1980   Lakers     2    0     1  240  48   95  0.505   0 ...   0.667   15
# 2  1980   Lakers     3    1     0  240  44   92  0.478   0 ...   0.767   22
# 3  1980   Lakers     4    0     0  240  44   93  0.473   0 ...   0.737   18
# 4  1980   Lakers     5    1     1  240  41   91  0.451   0 ...   0.788   19
# 5  1980   Lakers     6    1     0  240  45   92  0.489   0 ...   0.943   17
# 6  1981  Celtics     1    1     1  240  41   95  0.432   0 ...   0.800   25
# 7  1981  Celtics     2    0     1  240  41   82  0.500   0 ...   0.615   14
# 8  1981  Celtics     3    1     0  240  40   89  0.449   2 ...   0.632   16
# 9  1981  Celtics     4    0     0  240  35   74  0.473   0 ...   0.667   17
#
#    DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 0   31   43   30    5    9   17  24  109
# 1   37   52   32   12    7   26  27  104
# ...

# %%
def get_series_score(dataframe):
    series = []
    series_reversed = []
    dataframe.head()
    years = sorted(dataframe['Year'].unique())
    for year in years:
        home_team_score = 0
        away_team_score = 0
        
        games = max(dataframe[dataframe['Year']== year]['Game'])
        
        temp = dataframe[dataframe['Year']==year]
        temp = temp.head(len(temp)//2)
        
        for game in range(games):
            if temp.iloc[game]['Win'] == 1:
                home_team_score += 1
            else: 
                away_team_score += 1
            series_score = "{}-{}".format(home_team_score,away_team_score)
            series_reversed_score = "{}-{}".format(away_team_score,home_team_score)
            series.append(series_score)
            series_reversed.append(series_reversed_score)
            
    return series + series_reversed

# %%
def count_championships(dataframe):
    champions_dict = dict()
    years = df['Year'].unique()
    for year in years:
        champions_dict[year] = df[df['Year']==year]['Team'].iloc[0]
    return champions_dict

# %%
df['Series'] = pd.DataFrame(get_series_score(df))

# %%
df.head(10)
# Out:
#    Year     Team  Game  Win  Home   MP  FG  FGA    FGP  TP   ...    ORB  DRB  \
# 0  1980   Lakers     1    1     1  240  48   89  0.539   0   ...     12   31
# 1  1980   Lakers     2    0     1  240  48   95  0.505   0   ...     15   37
# 2  1980   Lakers     3    1     0  240  44   92  0.478   0   ...     22   34
# 3  1980   Lakers     4    0     0  240  44   93  0.473   0   ...     18   31
# 4  1980   Lakers     5    1     1  240  41   91  0.451   0   ...     19   37
# 5  1980   Lakers     6    1     0  240  45   92  0.489   0   ...     17   35
# 6  1981  Celtics     1    1     1  240  41   95  0.432   0   ...     25   29
# 7  1981  Celtics     2    0     1  240  41   82  0.500   0   ...     14   34
# 8  1981  Celtics     3    1     0  240  40   89  0.449   2   ...     16   28
# 9  1981  Celtics     4    0     0  240  35   74  0.473   0   ...     17   30
#
#    TRB  AST  STL  BLK  TOV  PF  PTS  Series
# 0   43   30    5    9   17  24  109     1-0
# ...

# %%
df_champions = pd.DataFrame.from_dict(count_championships(df), orient='index', columns=['Team'])

# %%
plt.figure(figsize=(10,5))
champ_plot = sns.countplot(df_champions['Team'], palette='viridis')

champ_plot.set_xticklabels(champ_plot.get_xticklabels(), rotation=40)
plt.ylabel('Championships')
plt.tight_layout()
plt.grid(alpha=0.3)
plt.show()

# %%
df['Series'] = get_series_score(df)

# %%
def get_mean(dataframe):
    mean = []

    dataframe = dataframe[['Year', 'Team', 'Game', 'Home', 'MP', 'FG', 'FGA', 'FGP', 'TP',
                           'TPA', 'TPP', 'FT', 'FTA', 'FTP', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
                           'BLK', 'TOV', 'PF', 'PTS', 'Series']]
    years = sorted(dataframe['Year'].unique())
    for year in years:
        temp = dataframe[dataframe['Year']==year]
        num_of_games = max(temp['Game'])
        
        # Upper - Winning team
        # Lower - Losing Team
        temp_upper = temp.head(len(temp)//2).mean()
        temp_lower =  temp.tail(len(temp)//2).mean()
        
        # Since using mean() will have a wrong value for the game column, we will replace it with the
        # max integer value of the game. Example, If a series has 4 games, using mean would return (1+2+3+4)/4 = 2.5,
        # instead, we will return 4 in this case
        temp_upper[1] = num_of_games 
        temp_lower[1] = num_of_games
        
        upper_home_away = temp['Home'].iloc[0]
        lower_home_away = temp['Home'].iloc[len(temp)//2]
        
        
        # Appending Series result
        series_result = pd.Series(dataframe[dataframe['Year']==year]['Series'].iloc[len(temp)//2-1])
        series_result_flip = pd.Series(dataframe[dataframe['Year']==year]['Series'].iloc[len(temp)-1])
        temp_upper = pd.concat([pd.Series([temp['Team'].iloc[0], upper_home_away, series_result[0]]), temp_upper])
        temp_lower = pd.concat([pd.Series([temp['Team'].iloc[len(temp)-1], lower_home_away, series_result_flip[0]]),
                                temp_lower])
        
        temp_upper = temp_upper.drop(index='Home')
        temp_lower = temp_lower.drop(index='Home')
        
        mean.append(temp_upper)
        mean.append(temp_lower)
    return mean

# %%
df_mean = pd.DataFrame(get_mean(df)).round(2)

# %%
df_mean.head()
# Out:
#          0  1    2    Year  Game     MP     FG    FGA   FGP    TP   ...    \
# 0   Lakers  1  4-2  1980.0   6.0  240.0  45.00  92.00  0.49  0.00   ...
# 1   Sixers  0  2-4  1980.0   6.0  240.0  43.00  88.33  0.49  0.17   ...
# 2  Celtics  1  4-2  1981.0   6.0  240.0  40.17  85.33  0.47  0.50   ...
# 3  Rockets  0  2-4  1981.0   6.0  240.0  33.83  89.33  0.38  0.50   ...
# 4   Lakers  0  4-2  1982.0   6.0  240.0  45.50  91.83  0.50  0.17   ...
#
#     FTP    ORB    DRB    TRB    AST    STL    BLK    TOV     PF     PTS
# 0  0.79  17.17  34.17  51.33  26.67   9.17   6.17  20.00  24.50  109.50
# 1  0.74   9.50  27.67  37.17  31.00   9.33  10.00  15.17  22.50  104.17
# 2  0.72  16.67  30.67  47.33  22.83   6.67   5.33  16.83  23.17   96.50
# 3  0.73  18.67  24.00  42.67  18.00   7.83   5.67  13.17  20.17   86.67
# 4  0.67  18.33  29.00  47.33  31.33  10.67   7.00  19.33  25.50  112.33
#
# [5 rows x 24 columns]

# %%
# Renaming some columns
df_mean.columns = ['Team', 'Homecourt', 'Series', 'Year', 'Game', 'MP', 'FG', 'FGA', 'FGP', 'TP',
                    'TPA', 'TPP', 'FT', 'FTA', 'FTP', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
                    'BLK', 'TOV', 'PF', 'PTS']
df_mean['Year'] = df_mean['Year'].apply(lambda x: int(x))
df_mean['Game'] = df_mean['Game'].apply(lambda x: int(x))
df_mean['Winner'] = df_mean['Series'].apply(lambda x: 1 if x[0]=='4' else 0)

# %%
df = df_mean.set_index('Year')

# %%
df.head()
# Out:
#          Team  Homecourt Series  Game     MP     FG    FGA   FGP    TP   TPA  \
# Year
# 1980   Lakers          1    4-2     6  240.0  45.00  92.00  0.49  0.00  0.67
# 1980   Sixers          0    2-4     6  240.0  43.00  88.33  0.49  0.17  2.67
# 1981  Celtics          1    4-2     6  240.0  40.17  85.33  0.47  0.50  2.83
# 1981  Rockets          0    2-4     6  240.0  33.83  89.33  0.38  0.50  1.83
# 1982   Lakers          0    4-2     6  240.0  45.50  91.83  0.50  0.17  1.50
#
#        ...      ORB    DRB    TRB    AST    STL    BLK    TOV     PF     PTS  \
# Year   ...
# 1980   ...    17.17  34.17  51.33  26.67   9.17   6.17  20.00  24.50  109.50
# 1980   ...     9.50  27.67  37.17  31.00   9.33  10.00  15.17  22.50  104.17
# 1981   ...    16.67  30.67  47.33  22.83   6.67   5.33  16.83  23.17   96.50
# 1981   ...    18.67  24.00  42.67  18.00   7.83   5.67  13.17  20.17   86.67
# 1982   ...    18.33  29.00  47.33  31.33  10.67   7.00  19.33  25.50  112.33
#
#       Winner
# Year
# ...

# %%
df.corr()
plt.figure(figsize=(15, 10))
mask =  np.zeros_like(df.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(df.corr(), annot=True, cmap='YlGnBu', mask=mask)

# %%
sns.countplot(hue='Winner', x='Homecourt', data=df)

# %%
#Game 7 Winners
game7s = df[df['Game']==7][['Winner','Homecourt']]
game7s = game7s[game7s['Winner']==1]

# %%
sns.countplot(x='Homecourt', data=game7s)

# %%
pd.
